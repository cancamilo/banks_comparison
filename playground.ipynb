# %%
# al 70% de hipoteca
inversion_total = 55_192
precio_piso = 106_665

# %%
arras = 10_665

prop_hero = 2_500 + 1000
dado = arras + prop_hero 

restante_prop_hero = 5500 - prop_hero
restante_prop_hero
# Out:
# 2000

# %%
# total pending fees
fees = 1500 + 12265 + 1150 + 465 + 1000 + 817 + 2000
fees
# Out:
# 19197

# %%
# total pending down payment
total_investment = 106_650 + fees
total = total_investment + 2500 + 1000

# %%
total - 3500 - arras - 40_000
# Out:
# 75182

# %%
precio_piso * 0.75
# Out:
# 79998.75
